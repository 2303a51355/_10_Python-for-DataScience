# %% [markdown]
# <a href="https://colab.research.google.com/github/2303a51355/_10_Python-for-DataScience/blob/main/Lab_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load dataset
df = pd.read_csv("/content/population (1).csv")

# Plot bar chart
plt.figure(figsize=(8,6))
plt.bar(df["Country"], df["Population"])

# Format y-axis labels to billions
plt.ylabel("Population (Billions)")
plt.title("Population of Top 5 Countries")

# Adjust y-axis
labels = plt.gca().get_yticks()
plt.gca().set_yticklabels([f"{x/1e9:.2f}B" for x in labels])

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-3205134673.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   plt.gca().set_yticklabels([f"{x/1e9:.2f}B" for x in labels])

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = {
    "Genre": ["Action", "Comedy", "Drama", "Horror", "Romance", "Sci-Fi", "Thriller"],
    "Movie_Count": [1200, 950, 1800, 600, 700, 500, 1100]
}

df = pd.DataFrame(data)
df.to_csv("movies_genre.csv", index=False)
print("Dataset saved as movies_genre.csv")

plt.figure(figsize=(8, 6))
plt.bar(df["Genre"], df["Movie_Count"])

plt.title("Number of Movies Produced by Genre")
plt.xlabel("Genre")
plt.ylabel("Movie Count")

plt.xticks(rotation=45)

plt.tight_layout()
plt.show()
# Out:
# Dataset saved as movies_genre.csv
